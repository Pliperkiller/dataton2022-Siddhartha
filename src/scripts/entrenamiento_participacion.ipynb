# %%
import requests
import re
import nltk
import random
import pandas as pd
import numpy as np

from nltk import FreqDist
from nltk import word_tokenize
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.util import ngrams
from bs4 import BeautifulSoup
from urllib import request
from url_config import *
from utilitools import *
from matplotlib import pyplot as plt

# %%
data = leer_paths('data')
recomendador = leer_paths('recomendador')
scripts = leer_paths('scripts')

# %%
# Esta función carga el archivo .csv que se encuentra en la ruta path con el nombre csv_file como un dataframe
def leer_csv(path,csv_file):
    '''
    Inserta ruta de carpeta donde se encuentra el archivo y nombre de archivo para hacer lectura de archivo como DataFrame
    '''
    for file in os.listdir(path):
        file_path = os.path.join(path,file)

        if csv_file in file_path:
            df = pd.read_csv(file_path)
    return df

# Se crea una función que realiza limpieza a la columna nombre, a través de expresiones regulares
def limpieza_clientes(df_clientes):
    df_clientes['nombre'] = df_clientes['nombre'].str.lower()
    df_clientes['nombre'] = df_clientes['nombre'].str.replace(r'[^a-z 0-9]', '',regex=True)
    df_clientes['nombre'] = df_clientes['nombre'].str.replace(r' s$', '',regex=True)
    df_clientes['nombre'] = df_clientes['nombre'].str.replace(r' e$', '',regex=True)
    df_clientes['nombre'] = df_clientes['nombre'].str.replace(r' d$', '',regex=True)

    df_clientes['nombre'] = df_clientes['nombre'].str.replace('cia','compania')

    tipi = [
        'sas',
        'sa',
        's a',
        's a s',
        'ltda',
        'limited',
        'limitada',
        'limit',
        'limitad',
        'sca',
        's c a',
        'esp',
        'e s p',
        'inc',
        's en c',
        'ci',
        'c i',
        'ltd',
        ]

    regstr = ''

    for term in tipi:
        regstr+=r'\s' + term +r'\b' + '|'

    df_clientes['nombre'] = df_clientes['nombre'].str.replace(regstr,'',regex=True)
    df_clientes['nombre'].str.strip()
    
    df_clientes['desc_ciiu_division'] = df_clientes['desc_ciiu_division'].str.lower()
    df_clientes['desc_ciuu_grupo'] = df_clientes['desc_ciuu_grupo'].str.lower()
    df_clientes['desc_ciiuu_clase'] = df_clientes['desc_ciiuu_clase'].str.lower()
    df_clientes['subsec'] = df_clientes['subsec'].str.lower()

    return df_clientes


def limpieza_noticias(df_noticias):
    df_noticias['news_title'] = df_noticias['news_title'].str.lower()
    df_noticias['news_text_content'] = df_noticias['news_text_content'].str.lower()
    return df_noticias

df_clientes = leer_csv(data,'clientes.csv')
df_clientes = limpieza_clientes(df_clientes)

df_noticias = leer_csv(data,'noticias.csv')
df_noticias = limpieza_noticias(df_noticias)

df_cn = leer_csv(data,'clientes_noticias.csv')

df_cn = df_cn[['nit','news_id']]
df_noticias = df_noticias[['news_id','news_title','news_text_content']]
BD = df_cn.merge(df_noticias, on='news_id',how='left')
BD = BD.merge(df_clientes, on='nit',how='left')
BD.dropna(inplace=True)

BD = BD.astype(str)

BD.head(5)

# %%
BD2 = BD.copy()

BD2['cliente'] = 0
BD2['sector'] = 0
BD2['no_aplica'] = 0
BD2['participacion'] = ''


for index, row in BD2.iterrows():
    if(row['nombre'] in row['news_title']):
        BD2['cliente'][index] += 1
    elif(row['nombre'] in row['news_text_content']):
        BD2['cliente'][index] += 1

    if(row['subsec'] in row['news_title']):
        BD2['sector'][index] += 1
    elif(row['subsec'] in row['news_text_content']):
        BD2['sector'][index] += 1

    if(BD2['sector'][index]==0 & BD2['cliente'][index] == 0):
        BD2['no_aplica'][index] += 1
    
    if(BD2['cliente'][index]==1): BD2['participacion'][index]+='cliente'
    elif(BD2['sector'][index]==1): BD2['participacion'][index]+='sector'
    else: BD2['participacion'][index]+='no aplica'

BD2
# Out:
# C:\Users\pipek\AppData\Local\Temp\ipykernel_34596\1778934483.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BD2['no_aplica'][index] += 1
# C:\Users\pipek\AppData\Local\Temp\ipykernel_34596\1778934483.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   else: BD2['participacion'][index]+='no aplica'
# C:\Users\pipek\AppData\Local\Temp\ipykernel_34596\1778934483.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BD2['sector'][index] += 1
# C:\Users\pipek\AppData\Local\Temp\ipykernel_34596\1778934483.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elif(BD2['sector'][index]==1): BD2['participacion'][index]+='sector'
# C:\Users\pipek\AppData\Local\Temp\ipykernel_34596\1778934483.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BD2['cliente'][index] += 1
# C:\Users\pipek\AppData\Local\Temp\ipykernel_34596\1778934483.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if(BD2['cliente'][index]==1): BD2['participacion'][index]+='cliente'
# C:\Users\pipek\AppData\Local\Temp\ipykernel_34596\1778934483.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BD2['cliente'][index] += 1
# C:\Users\pipek\AppData\Local\Temp\ipykernel_34596\1778934483.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BD2['sector'][index] += 1
#              nit    news_id  \
# 0      900378212  news10006
# 1      900378212  news10011
# 2      860034313  news10011
# 3      900378212  news10015
# 4      900166896  news10015
# ...          ...        ...
# 74704  800230209  news99997
# 74705  890209174  news99997
# 74706  830069311  news99997
# 74707  830130106  news99997
# 74708  890110188  news99997
#
#                                               news_title  \
# 0      precio dolar hoy: la cotizacion de la divisa a...
# 1      es cierto: el presidente gustavo petro quiere ...
# 2      es cierto: el presidente gustavo petro quiere ...
# 3      gustavo petro: ?que dice el informe final de s...
# 4      gustavo petro: ?que dice el informe final de s...
# ...                                                  ...
# 74704  en cucuta subio el desempleo en junio y fue de...
# 74705  en cucuta subio el desempleo en junio y fue de...
# 74706  en cucuta subio el desempleo en junio y fue de...
# 74707  en cucuta subio el desempleo en junio y fue de...
# 74708  en cucuta subio el desempleo en junio y fue de...
#
#                                        news_text_content  \
# 0      este martes, 2 de agosto, el dolar alcanzo un ...
# 1      no hay nada mas permanente que lo temporal y a...
# 2      no hay nada mas permanente que lo temporal y a...
# 3      el equipo de empalme del gobierno del presiden...
# 4      el equipo de empalme del gobierno del presiden...
# ...                                                  ...
# 74704  este viernes, el departamento administrativo n...
# 74705  este viernes, el departamento administrativo n...
# 74706  este viernes, el departamento administrativo n...
# 74707  este viernes, el departamento administrativo n...
# 74708  este viernes, el departamento administrativo n...
#
#                                       nombre  \
# 0                                    banco w
# 1                                    banco w
# 2                           banco davivienda
# 3                                    banco w
# 4         hino motors manufacturing colombia
# ...                                      ...
# 74704                   weatherford colombia
# 74705                                ismocol
# 74706  nabors drilling international bermuda
# 74707        soenergy international colombia
# 74708                  independence drilling
#
#                                       desc_ciiu_division  \
# 0      actividades de servicios financieros, excepto ...
# 1      actividades de servicios financieros, excepto ...
# 2      actividades de servicios financieros, excepto ...
# 3      actividades de servicios financieros, excepto ...
# 4      fabricacion de vehiculos automotores, remolque...
# ...                                                  ...
# 74704  actividades de servicios de apoyo para la expl...
# 74705  actividades de servicios de apoyo para la expl...
# 74706  actividades de servicios de apoyo para la expl...
# 74707  actividades de servicios de apoyo para la expl...
# 74708  actividades de servicios de apoyo para la expl...
#
#                                          desc_ciuu_grupo  \
# 0                               intermediacion monetaria
# 1                               intermediacion monetaria
# 2                               intermediacion monetaria
# 3                               intermediacion monetaria
# 4      fabricacion de vehiculos automotores y sus mot...
# ...                                                  ...
# 74704  actividades de apoyo para la extraccion de pet...
# 74705  actividades de apoyo para la extraccion de pet...
# 74706  actividades de apoyo para la extraccion de pet...
# 74707  actividades de apoyo para la extraccion de pet...
# 74708  actividades de apoyo para la extraccion de pet...
#
#                                         desc_ciiuu_clase  \
# 0                                     bancos comerciales
# 1                                     bancos comerciales
# 2                                     bancos comerciales
# 3                                     bancos comerciales
# 4      fabricacion de vehiculos automotores y sus mot...
# ...                                                  ...
# 74704  actividades de apoyo para la extraccion de pet...
# 74705  actividades de apoyo para la extraccion de pet...
# 74706  actividades de apoyo para la extraccion de pet...
# 74707  actividades de apoyo para la extraccion de pet...
# 74708  actividades de apoyo para la extraccion de pet...
#
#                        subsec  cliente  sector  no_aplica participacion
# 0                      bancos        0       0          1     no aplica
# 1                      bancos        0       1          0        sector
# 2                      bancos        0       1          0        sector
# 3                      bancos        0       0          1     no aplica
# 4        equipo de transporte        0       0          1     no aplica
# ...                       ...      ...     ...        ...           ...
# 74704  extraccion de petroleo        0       0          1     no aplica
# 74705  extraccion de petroleo        0       0          1     no aplica
# 74706  extraccion de petroleo        0       0          1     no aplica
# 74707                     gas        0       0          1     no aplica
# 74708  extraccion de petroleo        0       0          1     no aplica
#
# [74617 rows x 13 columns]

# %%
df_participacion = BD2.copy()
df_participacion.to_csv(os.path.join(data,r'output/participacion.csv'),index=False)

# %%
df_categorizacion = pd.read_csv(os.path.join(data,r'output/categorizacion.csv'))
df_participacion = pd.read_csv(os.path.join(data,r'output/participacion.csv'))
df_categorizacion = df_categorizacion[['news_id','clase']]
#df_cat2 = df_participacion.drop(columns=['desc_ciiu_division','desc_ciuu_grupo','desc_ciiuu_clase','cliente','sector','no_aplica'])
df_cat2 = df_participacion.merge(df_categorizacion,on='news_id',how='left')
df_cat2['clase'] = np.where((df_cat2['clase'] == 'Otras') & (df_cat2['participacion'] == 'no aplica'),'Descartable',df_cat2['clase'])

# %%
#1. Aporte al conocimiento del cliente
#Sacar tokens de 
stops = stopwords.words('spanish')
regex = re.compile('[^a-zA-Z]')


def clean_tokens(token_list):
    token_list = sorted(set(token_list))
    filtered_tokens = [token for token in token_list if token not in stops]

    return filtered_tokens


def token_influence(tokens1,tokens2):
    freq_t2 = FreqDist(tokens2)
    count = 0
    for token in tokens1:
        count+=freq_t2[token]
    return count


def tokenize_df(df):
    df2 = pd.DataFrame()
    df2['client_strings'] = df[['desc_ciiu_division','desc_ciuu_grupo','desc_ciiuu_clase']].apply(lambda x: ', '.join(x[x.notnull()]), axis = 1)
    df2['client_strings'].str.lower()
    df2['client_strings'] = df2['client_strings'].str.replace(r'[^A-Za-z\s]+', '')
    
    df2['news_strings'] = df[['news_title','news_text_content']].apply(lambda x: ', '.join(x[x.notnull()]), axis = 1)
    df2['news_strings'].str.lower()
    df2['news_strings'] = df2['news_strings'].str.replace(r'[^A-Za-z\s]+', '')

    df2['tokens'] = df2.apply(lambda row: nltk.word_tokenize(row['client_strings']), axis=1)

    df['n_tokens'] = df2.apply(lambda row: nltk.word_tokenize(row['news_strings']), axis=1)
    df['client_tokens'] = df2['tokens'].apply(clean_tokens)

# %%
tokenize_df(df_cat2)

df_cat2

# %%
def token_influence(tokens1,tokens2):
    freq_t2 = FreqDist(tokens2)
    count = 0
    for token in tokens1:
        count+=freq_t2[token]
    return count


df_cat2['influencia_cliente'] = df_cat2.apply(lambda x: token_influence(x.client_tokens,x.n_tokens),axis=1)
df_cat2['influencia_cliente'].describe()
# Out:
# count    74617.000000
# mean         5.650120
# std         42.389742
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          5.000000
# max       1620.000000
# Name: influencia_cliente, dtype: float64

# %%
df_cat2.to_csv(os.path.join(data,r'output/recomendacion.csv'),index=False)

# %%
df_rec = pd.read_csv(os.path.join(data,r'output/recomendacion.csv'))

# %%
#Thresh influencia: 1p - 5, 2p-10
def inf_score(value):
    score = 0
    if value>=5: score+=1
    if value>=10: score+=1

    return score

def client_score(value):
    if value == 1: return 2
    else: return 0

def sec_score(value):
    if value == 1: return 1
    else: return 0

def len_score(value):
    score = 0
    if value>=500: score+=1

    return score

boxplot = df_rec.boxplot(column=['influencia_cliente'],showfliers=False)

# %%
def clean_tokens(token_list):
    
    filtered_tokens = [token for token in token_list if token not in stops]

    return filtered_tokens

df2 = pd.DataFrame()
df2['n_tokens'] = df_rec['n_tokens']
df2['n_clean_tokens'] = df_rec['n_tokens'].apply(clean_tokens)
df2['n_len'] = df2['n_clean_tokens'].apply(len)
boxplot = df2.boxplot(column=['n_len'],showfliers=False)

# %%
df2[]
# Out:
#               n_len
# count  7.461700e+04
# mean   1.207318e+04
# std    1.089275e+05
# min    3.300000e+01
# 25%    2.125000e+03
# 50%    3.522000e+03
# 75%    5.551000e+03
# max    1.763444e+06

# %%
df_rec.sort_values(by=['nit'],inplace=True)
df_rec[df_rec['nit']==800000946]
# Out:
#              nit    news_id  \
# 64396  800000946  news97845
# 64579  800000946  news97860
# 63975  800000946  news97669
# 44986  800000946  news89860
# 37859  800000946  news69546
# 64435  800000946  news97846
# 48436  800000946  news95244
# 44984  800000946  news89850
# 64357  800000946  news97841
# 9338   800000946  news18687
# 44985  800000946  news89859
# 47172  800000946  news94698
# 64513  800000946  news97858
# 2022   800000946  news12670
# 64474  800000946  news97853
# 6556   800000946  news15986
#
#                                               news_title  \
# 64396  fueron absueltos estudiantes universitarios ac...
# 64579  gustavo petro propone legalizar el "cannabis e...
# 63975  banco central: economia dominicana crecio un 5...
# 44986             wall street cierra el viernes en verde
# 37859  wall street cierra a la baja este viernes y el...
# 64435  inauguran laboratorio quimico de investigacion...
# 48436  oit lanza curso gratuito para prevenir acciden...
# 44984                                        pagina 9954
# 64357  ganancias de fabricantes de chips en ee.uu. po...
# 9338   propoleo como alternativa natural para conserv...
# 44985  wall street termina al alza su mejor mes del a...
# 47172  bebidas organicas y veganas: novedades de expo...
# 64513  el indice de produccion industrial se ubico en...
# 2022   autogermana recibio distincion al mejor import...
# 64474  inauguran laboratorio quimico de investigacion...
# 6556   guia de arte y cultura: semana del 12 al 19 de...
#
#                                        news_text_content  \
# 64396  despues de diez anos, cuatro meses y 28 dias, ...
# 64579  el nuevo presidente de colombia, gustavo petro...
# 63975  el indicador mensual de actividad economica (i...
# 44986  wall street cerro en verde este viernes y el d...
# 37859  wall street cerro este viernes en rojo y el do...
# 64435  el ministro de justicia y del derecho, wilson ...
# 48436  lima - la oit, en el marco del proyecto del fo...
# 44984  el informe ofrece los desarrollos regionales d...
# 64357  bloomberg -- la ley "chips y ciencia" que el p...
# 9338    el profesor hector suarez mahecha, del instit...
# 44985  la bolsa de nueva york finalizo con nota posit...
# 47172  tras dos anos de realizarse en formato virtual...
# 64513  el departamento administrativo nacional de est...
# 2022   autogermana recibio una distincion como el mej...
# 64474  el ministro de justicia, wilson ruiz orejuela,...
# 6556   arte agustina galindez quesada exhibe "catarsi...
#
#                          nombre  \
# 64396  procter  gamble colombia
# 64579  procter  gamble colombia
# 63975  procter  gamble colombia
# 44986  procter  gamble colombia
# 37859  procter  gamble colombia
# 64435  procter  gamble colombia
# 48436  procter  gamble colombia
# 44984  procter  gamble colombia
# 64357  procter  gamble colombia
# 9338   procter  gamble colombia
# 44985  procter  gamble colombia
# 47172  procter  gamble colombia
# 64513  procter  gamble colombia
# 2022   procter  gamble colombia
# 64474  procter  gamble colombia
# 6556   procter  gamble colombia
#
#                                    desc_ciiu_division  \
# 64396  fabricacion de sustancias y productos quimicos
# 64579  fabricacion de sustancias y productos quimicos
# 63975  fabricacion de sustancias y productos quimicos
# 44986  fabricacion de sustancias y productos quimicos
# 37859  fabricacion de sustancias y productos quimicos
# 64435  fabricacion de sustancias y productos quimicos
# 48436  fabricacion de sustancias y productos quimicos
# 44984  fabricacion de sustancias y productos quimicos
# 64357  fabricacion de sustancias y productos quimicos
# 9338   fabricacion de sustancias y productos quimicos
# 44985  fabricacion de sustancias y productos quimicos
# 47172  fabricacion de sustancias y productos quimicos
# 64513  fabricacion de sustancias y productos quimicos
# 2022   fabricacion de sustancias y productos quimicos
# 64474  fabricacion de sustancias y productos quimicos
# 6556   fabricacion de sustancias y productos quimicos
#
#                                desc_ciuu_grupo  \
# 64396  fabricacion de otros productos quimicos
# 64579  fabricacion de otros productos quimicos
# 63975  fabricacion de otros productos quimicos
# 44986  fabricacion de otros productos quimicos
# 37859  fabricacion de otros productos quimicos
# 64435  fabricacion de otros productos quimicos
# 48436  fabricacion de otros productos quimicos
# 44984  fabricacion de otros productos quimicos
# 64357  fabricacion de otros productos quimicos
# 9338   fabricacion de otros productos quimicos
# 44985  fabricacion de otros productos quimicos
# 47172  fabricacion de otros productos quimicos
# 64513  fabricacion de otros productos quimicos
# 2022   fabricacion de otros productos quimicos
# 64474  fabricacion de otros productos quimicos
# 6556   fabricacion de otros productos quimicos
#
#                                         desc_ciiuu_clase  \
# 64396  fabricacion de jabones y detergentes, preparad...
# 64579  fabricacion de jabones y detergentes, preparad...
# 63975  fabricacion de jabones y detergentes, preparad...
# 44986  fabricacion de jabones y detergentes, preparad...
# 37859  fabricacion de jabones y detergentes, preparad...
# 64435  fabricacion de jabones y detergentes, preparad...
# 48436  fabricacion de jabones y detergentes, preparad...
# 44984  fabricacion de jabones y detergentes, preparad...
# 64357  fabricacion de jabones y detergentes, preparad...
# 9338   fabricacion de jabones y detergentes, preparad...
# 44985  fabricacion de jabones y detergentes, preparad...
# 47172  fabricacion de jabones y detergentes, preparad...
# 64513  fabricacion de jabones y detergentes, preparad...
# 2022   fabricacion de jabones y detergentes, preparad...
# 64474  fabricacion de jabones y detergentes, preparad...
# 6556   fabricacion de jabones y detergentes, preparad...
#
#                                                   subsec  cliente  sector  \
# 64396  manufactura de productos de tocador y articulo...        0       0
# 64579  manufactura de productos de tocador y articulo...        0       0
# 63975  manufactura de productos de tocador y articulo...        0       0
# 44986  manufactura de productos de tocador y articulo...        0       0
# 37859  manufactura de productos de tocador y articulo...        0       0
# 64435  manufactura de productos de tocador y articulo...        0       0
# 48436  manufactura de productos de tocador y articulo...        0       0
# 44984  manufactura de productos de tocador y articulo...        0       0
# 64357  manufactura de productos de tocador y articulo...        0       0
# 9338   manufactura de productos de tocador y articulo...        0       0
# 44985  manufactura de productos de tocador y articulo...        0       0
# 47172  manufactura de productos de tocador y articulo...        0       0
# 64513  manufactura de productos de tocador y articulo...        0       0
# 2022   manufactura de productos de tocador y articulo...        0       0
# 64474  manufactura de productos de tocador y articulo...        0       0
# 6556   manufactura de productos de tocador y articulo...        0       0
#
#        no_aplica participacion          clase  \
# 64396          1     no aplica  Macroeconomía
# 64579          1     no aplica   Regulaciones
# 63975          1     no aplica  Macroeconomía
# 44986          1     no aplica  Macroeconomía
# 37859          1     no aplica  Macroeconomía
# 64435          1     no aplica  Macroeconomía
# 48436          1     no aplica     Innovación
# 44984          1     no aplica  Macroeconomía
# 64357          1     no aplica  Macroeconomía
# 9338           1     no aplica  Macroeconomía
# 44985          1     no aplica  Macroeconomía
# 47172          1     no aplica  Macroeconomía
# 64513          1     no aplica  Macroeconomía
# 2022           1     no aplica        Alianza
# 64474          1     no aplica  Macroeconomía
# 6556           1     no aplica  Macroeconomía
#
#                                                 n_tokens  \
# 64396  ['fueron', 'absueltos', 'estudiantes', 'univer...
# 64579  ['gustavo', 'petro', 'propone', 'legalizar', '...
# 63975  ['banco', 'central', 'economia', 'dominicana',...
# 44986  ['wall', 'street', 'cierra', 'el', 'viernes', ...
# 37859  ['wall', 'street', 'cierra', 'a', 'la', 'baja'...
# 64435  ['inauguran', 'laboratorio', 'quimico', 'de', ...
# 48436  ['oit', 'lanza', 'curso', 'gratuito', 'para', ...
# 44984  ['pagina', 'el', 'informe', 'ofrece', 'los', '...
# 64357  ['ganancias', 'de', 'fabricantes', 'de', 'chip...
# 9338   ['propoleo', 'como', 'alternativa', 'natural',...
# 44985  ['wall', 'street', 'termina', 'al', 'alza', 's...
# 47172  ['bebidas', 'organicas', 'y', 'veganas', 'nove...
# 64513  ['el', 'indice', 'de', 'produccion', 'industri...
# 2022   ['autogermana', 'recibio', 'distincion', 'al',...
# 64474  ['inauguran', 'laboratorio', 'quimico', 'de', ...
# 6556   ['guia', 'de', 'arte', 'y', 'cultura', 'semana...
#
#                                            client_tokens  influencia_cliente
# 64396  ['detergentes', 'fabricacion', 'jabones', 'lim...                   5
# 64579  ['detergentes', 'fabricacion', 'jabones', 'lim...                   0
# 63975  ['detergentes', 'fabricacion', 'jabones', 'lim...                   9
# 44986  ['detergentes', 'fabricacion', 'jabones', 'lim...                   0
# 37859  ['detergentes', 'fabricacion', 'jabones', 'lim...                   0
# 64435  ['detergentes', 'fabricacion', 'jabones', 'lim...                  11
# 48436  ['detergentes', 'fabricacion', 'jabones', 'lim...                   7
# 44984  ['detergentes', 'fabricacion', 'jabones', 'lim...                   1
# 64357  ['detergentes', 'fabricacion', 'jabones', 'lim...                   5
# 9338   ['detergentes', 'fabricacion', 'jabones', 'lim...                   4
# 44985  ['detergentes', 'fabricacion', 'jabones', 'lim...                   0
# 47172  ['detergentes', 'fabricacion', 'jabones', 'lim...                   5
# 64513  ['detergentes', 'fabricacion', 'jabones', 'lim...                   8
# 2022   ['detergentes', 'fabricacion', 'jabones', 'lim...                   0
# 64474  ['detergentes', 'fabricacion', 'jabones', 'lim...                  11
# 6556   ['detergentes', 'fabricacion', 'jabones', 'lim...                   2

# %%
df_rec[df_rec['influencia_cliente']==1620]
# Out:
#             nit    news_id                                         news_title  \
# 4607  800183987  news14869  las empresas ante a la reactivacion economica ...
# 4609  804009752  news14869  las empresas ante a la reactivacion economica ...
# 4794  811007303  news14869  las empresas ante a la reactivacion economica ...
# 4789  811016206  news14869  las empresas ante a la reactivacion economica ...
# 4792  830077032  news14869  las empresas ante a la reactivacion economica ...
# 4626  860006773  news14869  las empresas ante a la reactivacion economica ...
# 4790  860007327  news14869  las empresas ante a la reactivacion economica ...
# 4618  860029200  news14869  las empresas ante a la reactivacion economica ...
# 4793  890300625  news14869  las empresas ante a la reactivacion economica ...
# 4791  890300634  news14869  las empresas ante a la reactivacion economica ...
# 4788  900085162  news14869  las empresas ante a la reactivacion economica ...
# 4795  901490872  news14869  las empresas ante a la reactivacion economica ...
#
#                                       news_text_content  \
# 4607   el sector servicios elevo su facturacion un 1...
# 4609   el sector servicios elevo su facturacion un 1...
# 4794   el sector servicios elevo su facturacion un 1...
# 4789   el sector servicios elevo su facturacion un 1...
# 4792   el sector servicios elevo su facturacion un 1...
# 4626   el sector servicios elevo su facturacion un 1...
# 4790   el sector servicios elevo su facturacion un 1...
# 4618   el sector servicios elevo su facturacion un 1...
# 4793   el sector servicios elevo su facturacion un 1...
# 4791   el sector servicios elevo su facturacion un 1...
# 4788   el sector servicios elevo su facturacion un 1...
# 4795   el sector servicios elevo su facturacion un 1...
#
#                                                  nombre  \
# 4607                 fondo de empleados almacenes exito
# 4609       cooperativa de ahorro y credito de santander
# 4794                           fondo de empleados feiro
# 4789                fondo de empleados grupo santamaria
# 4792                     fondo de empleados de manpower
# 4626  fondo de empleados de los trabajadores y pensi...
# 4790        cooperativa de ahorro y credito fincomercio
# 4618           fondo de empleados del banco de colombia
# 4793  coop medica del valle y de profnales de co coo...
# 4791   coop de trabajadores de la organizacion carvajal
# 4788  fondo de empleados de empresas agropecuarias y...
# 4795                fondo de empleados offcorss hermeco
#
#                                      desc_ciiu_division  \
# 4607  actividades de servicios financieros, excepto ...
# 4609  actividades de servicios financieros, excepto ...
# 4794  actividades de servicios financieros, excepto ...
# 4789  actividades de servicios financieros, excepto ...
# 4792  actividades de servicios financieros, excepto ...
# 4626  actividades de servicios financieros, excepto ...
# 4790  actividades de servicios financieros, excepto ...
# 4618  actividades de servicios financieros, excepto ...
# 4793  actividades de servicios financieros, excepto ...
# 4791  actividades de servicios financieros, excepto ...
# 4788  actividades de servicios financieros, excepto ...
# 4795  actividades de servicios financieros, excepto ...
#
#                                         desc_ciuu_grupo  \
# 4607  otras actividades de servicio financiero, exce...
# 4609  otras actividades de servicio financiero, exce...
# 4794  otras actividades de servicio financiero, exce...
# 4789  otras actividades de servicio financiero, exce...
# 4792  otras actividades de servicio financiero, exce...
# 4626  otras actividades de servicio financiero, exce...
# 4790  otras actividades de servicio financiero, exce...
# 4618  otras actividades de servicio financiero, exce...
# 4793  otras actividades de servicio financiero, exce...
# 4791  otras actividades de servicio financiero, exce...
# 4788  otras actividades de servicio financiero, exce...
# 4795  otras actividades de servicio financiero, exce...
#
#                                        desc_ciiuu_clase  \
# 4607  actividades financieras de fondos de empleados...
# 4609  actividades financieras de fondos de empleados...
# 4794  actividades financieras de fondos de empleados...
# 4789  actividades financieras de fondos de empleados...
# 4792  actividades financieras de fondos de empleados...
# 4626  actividades financieras de fondos de empleados...
# 4790  actividades financieras de fondos de empleados...
# 4618  actividades financieras de fondos de empleados...
# 4793  actividades financieras de fondos de empleados...
# 4791  actividades financieras de fondos de empleados...
# 4788  actividades financieras de fondos de empleados...
# 4795  actividades financieras de fondos de empleados...
#
#                            subsec  cliente  sector  no_aplica participacion  \
# 4607  otros servicios financieros        0       0          1     no aplica
# 4609  otros servicios financieros        0       0          1     no aplica
# 4794  otros servicios financieros        0       0          1     no aplica
# 4789  otros servicios financieros        0       0          1     no aplica
# 4792  otros servicios financieros        0       0          1     no aplica
# 4626  otros servicios financieros        0       0          1     no aplica
# 4790  otros servicios financieros        0       0          1     no aplica
# 4618  otros servicios financieros        0       0          1     no aplica
# 4793  otros servicios financieros        0       0          1     no aplica
# 4791  otros servicios financieros        0       0          1     no aplica
# 4788  otros servicios financieros        0       0          1     no aplica
# 4795  otros servicios financieros        0       0          1     no aplica
#
#               clase                                           n_tokens  \
# 4607  Macroeconomía  ['las', 'empresas', 'ante', 'a', 'la', 'reacti...
# 4609  Macroeconomía  ['las', 'empresas', 'ante', 'a', 'la', 'reacti...
# 4794  Macroeconomía  ['las', 'empresas', 'ante', 'a', 'la', 'reacti...
# 4789  Macroeconomía  ['las', 'empresas', 'ante', 'a', 'la', 'reacti...
# 4792  Macroeconomía  ['las', 'empresas', 'ante', 'a', 'la', 'reacti...
# 4626  Macroeconomía  ['las', 'empresas', 'ante', 'a', 'la', 'reacti...
# 4790  Macroeconomía  ['las', 'empresas', 'ante', 'a', 'la', 'reacti...
# 4618  Macroeconomía  ['las', 'empresas', 'ante', 'a', 'la', 'reacti...
# 4793  Macroeconomía  ['las', 'empresas', 'ante', 'a', 'la', 'reacti...
# 4791  Macroeconomía  ['las', 'empresas', 'ante', 'a', 'la', 'reacti...
# 4788  Macroeconomía  ['las', 'empresas', 'ante', 'a', 'la', 'reacti...
# 4795  Macroeconomía  ['las', 'empresas', 'ante', 'a', 'la', 'reacti...
#
#                                           client_tokens  influencia_cliente
# 4607  ['actividades', 'asociativas', 'empleados', 'e...                1620
# 4609  ['actividades', 'asociativas', 'empleados', 'e...                1620
# 4794  ['actividades', 'asociativas', 'empleados', 'e...                1620
# 4789  ['actividades', 'asociativas', 'empleados', 'e...                1620
# 4792  ['actividades', 'asociativas', 'empleados', 'e...                1620
# 4626  ['actividades', 'asociativas', 'empleados', 'e...                1620
# 4790  ['actividades', 'asociativas', 'empleados', 'e...                1620
# 4618  ['actividades', 'asociativas', 'empleados', 'e...                1620
# 4793  ['actividades', 'asociativas', 'empleados', 'e...                1620
# 4791  ['actividades', 'asociativas', 'empleados', 'e...                1620
# 4788  ['actividades', 'asociativas', 'empleados', 'e...                1620
# 4795  ['actividades', 'asociativas', 'empleados', 'e...                1620
